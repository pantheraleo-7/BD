# %% [markdown]
# ## WAP to find word count.

# %%
from pyspark import SparkContext

# %%
sc = SparkContext()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/02 07:29:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/04/02 07:29:40 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
file = sc.textFile('datasets/poem.txt')

# %%
file.flatMap(lambda line: line.split()).countByValue()
# Out:
# defaultdict(int,
#             {'दीप': 1,
#              'जिस': 1,
#              'का': 1,
#              'महल्लात': 1,
#              'ही': 1,
#              'में': 2,
#              'जले': 1,
#              'चंद': 1,
#              'लोगों': 1,
#              'की': 5,
#              'ख़ुशियों': 1,
#              'को': 8,
#              'ले': 1,
#              'कर': 1,
#              'चले': 1,
#              'वो': 1,
#              'जो': 1,
#              'साए': 1,
#              'हर': 1,
#              'मस्लहत': 1,
#              'के': 3,
#              'पले': 1,
#              'ऐसे': 1,
#              'दस्तूर': 1,
#              'सुब्ह-ए-बे-नूर': 1,
#              'मैं': 10,
#              'नहीं': 10,
#              'मानता': 4,
#              'जानता': 4,
#              'भी': 2,
#              'ख़ाइफ़': 1,
#              'तख़्ता-ए-दार': 1,
#              'से': 3,
#              'मंसूर': 1,
#              'हूँ': 1,
#              'कह': 1,
#              'दो': 1,
# ...
